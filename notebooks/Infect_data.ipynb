# %%
import pandas as pd
import numpy as np
import random

# %%
file_path = "../data/churn.csv"
df = pd.read_csv(file_path)

# %%
def infect_data(df):
    df_copy = df.copy()

    # 1. Inject Missing Values
    def inject_missing_values(df):
        num_missing = int(df.size * 0.05)
        for _ in range(num_missing):
            ix = (random.randint(0, df.shape[0]-1), random.randint(0, df.shape[1]-1))
            df.iat[ix] = np.nan
        return df

    # 2. Inject Incorrect Data Types
    def inject_incorrect_data_types(df):
        for col in df.select_dtypes(include=['number']).columns:
            df[col] = df[col].apply(lambda x: str(x) if random.random() < 0.05 else x)
        return df

    # 3. Inject Duplicate Rows
    def inject_duplicate_rows(df):
        num_dup = int(df.shape[0] * 0.05)
        dup_rows = df.sample(num_dup, replace=True)
        df = pd.concat([df, dup_rows], ignore_index=True)
        return df

    # 4. Inject Outliers
    def inject_outliers(df):
        for col in df.select_dtypes(include=['number']).columns:
            df[col] = df[col].apply(lambda x: x*10 if random.random() < 0.05 else x)
        return df

    # 5. Inject Inconsistent Data Formats
    def inject_inconsistent_formats(df):
        for col in df.select_dtypes(include=['object']).columns:
            df[col] = df[col].apply(lambda x: f"{x}-badformat" if random.random() < 0.05 else x)
        return df

    # 6. Inject Invalid Range Values
    def inject_invalid_range(df):
        for col in df.columns:
            if "age" in col.lower():
                df[col] = df[col].apply(lambda x: -x if random.random() < 0.05 else x)
        return df

    # 7. Inject Unexpected Categorical Values
    def inject_unexpected_categories(df):
        for col in df.select_dtypes(include=['object']).columns:
            unique_vals = df[col].unique().tolist()
            if len(unique_vals) > 2:  # For categorical columns
                df[col] = df[col].apply(lambda x: "InvalidCategory" if random.random() < 0.05 else x)
        return df

    # Apply all infections
    df_copy = inject_missing_values(df_copy)
    df_copy = inject_incorrect_data_types(df_copy)
    df_copy = inject_duplicate_rows(df_copy)
    df_copy = inject_outliers(df_copy)
    df_copy = inject_inconsistent_formats(df_copy)
    df_copy = inject_invalid_range(df_copy)
    df_copy = inject_unexpected_categories(df_copy)

    return df_copy

# %%
infected_df = infect_data(df)

# %%
infected_df
# Out:
#                 customerID  gender SeniorCitizen Partner Dependents  \
# 0               7590-VHVEG  Female           0.0     Yes         No
# 1               5575-GNVDE    Male           0.0      No         No
# 2               3668-QPYBK    Male           0.0      No         No
# 3               7795-CFOCW     NaN           0.0      No         No
# 4               9237-HQITU  Female           0.0     NaN         No
# ...                    ...     ...           ...     ...        ...
# 7390            5893-KCLGT  Female           0.0      No        Yes
# 7391            0567-XRHCU  Female           0.0     Yes        Yes
# 7392            8167-GJLRN    Male           0.0      No         No
# 7393            2450-ZKEED  Female           0.0      No         No
# 7394  0254-KCJGT-badformat    Male           0.0     Yes         No
#
#                tenure PhoneService     MultipleLines InternetService  \
# 0                 NaN           No  No phone service             DSL
# 1                34.0          Yes                No             DSL
# 2     InvalidCategory          Yes   InvalidCategory             DSL
# 3     InvalidCategory           No  No phone service             DSL
# 4                 2.0          Yes                No     Fiber optic
# ...               ...          ...               ...             ...
# 7390             72.0          Yes                No              No
# 7391   69.0-badformat           No  No phone service             DSL
# 7392              3.0           No  No phone service             DSL
# 7393             11.0          Yes                No   DSL-badformat
# 7394             52.0          Yes               Yes             DSL
#
#            OnlineSecurity  ...     DeviceProtection          TechSupport  \
# 0                      No  ...                   No                   No
# 1                     Yes  ...                  Yes                   No
# 2                     Yes  ...                   No                   No
# 3                     Yes  ...        Yes-badformat                  Yes
# 4                      No  ...                   No                   No
# ...                   ...  ...                  ...                  ...
# 7390  No internet service  ...  No internet service  No internet service
# 7391                  Yes  ...                  Yes      InvalidCategory
# 7392                   No  ...                   No                  Yes
# 7393                   No  ...                  Yes                  Yes
# 7394                  Yes  ...                  Yes                  Yes
#
#                         StreamingTV      StreamingMovies         Contract  \
# 0                                No                   No   Month-to-month
# 1                                No                   No         One year
# 2                                No                   No   Month-to-month
# 3                                No                   No  InvalidCategory
# 4                                No                   No              NaN
# ...                             ...                  ...              ...
# 7390  No internet service-badformat  No internet service         Two year
# 7391                             No                  Yes         Two year
# 7392                             No                   No   Month-to-month
# 7393                             No                   No         One year
# 7394                             No                  Yes              NaN
#
#      PaperlessBilling              PaymentMethod   MonthlyCharges  \
# 0                 Yes           Electronic check            29.85
# 1        No-badformat               Mailed check            56.95
# 2                 Yes               Mailed check            53.85
# 3                  No  Bank transfer (automatic)             42.3
# 4                 Yes           Electronic check   70.7-badformat
# ...               ...                        ...              ...
# 7390              Yes               Mailed check            19.75
# 7391              Yes    Credit card (automatic)            43.95
# 7392     No-badformat           Electronic check   30.4-badformat
# 7393               No  Bank transfer (automatic)  InvalidCategory
# 7394              Yes    Credit card (automatic)             81.4
#
#           TotalCharges Churn
# 0      29.85-badformat    No
# 1               1889.5    No
# 2               108.15   Yes
# 3              1840.75    No
# 4               151.65   Yes
# ...                ...   ...
# 7390              1567    No
# 7391            2960.1    No
# 7392             82.15    No
# 7393  651.55-badformat    No
# 7394           4354.45    No
#
# [7395 rows x 21 columns]

# %%
# Save the infected dataset
infected_df.to_csv("../data/infected_dataset.csv", index=False)

# Display a sample of the infected data
infected_df.sample(10)
# Out:
#       customerID  gender SeniorCitizen        Partner Dependents  \
# 419   5564-NEMQO     NaN           1.0  nan-badformat         No
# 1743  3768-VHXQO    Male           0.0            Yes         No
# 4473  2665-NPTGL  Female           1.0            Yes         No
# 3431  2430-USGXP    Male           0.0            Yes         No
# 2740  0415-MOSGF  Female           0.0             No         No
# 1614  3813-DHBBB    Male           0.0            Yes         No
# 7353  9172-ANCRX  Female           0.0             No         No
# 1434  1571-SAVHK    Male           0.0             No         No
# 1337  6265-FRMTQ     NaN           0.0             No         No
# 34    3413-BMNZE    Male           1.0             No         No
#
#                tenure   PhoneService     MultipleLines  InternetService  \
# 419   InvalidCategory            Yes                No      Fiber optic
# 1743             67.0            Yes               NaN               No
# 4473             26.0  Yes-badformat               Yes      Fiber optic
# 3431             24.0            Yes               Yes      Fiber optic
# 2740              1.0            Yes                No              DSL
# 1614             67.0             No  No phone service              DSL
# 7353             10.0            Yes               Yes      Fiber optic
# 1434             12.0            Yes               Yes  InvalidCategory
# 1337             31.0            Yes                No               No
# 34    InvalidCategory            NaN   InvalidCategory              DSL
#
#            OnlineSecurity  ...     DeviceProtection          TechSupport  \
# 419          No-badformat  ...                  Yes                   No
# 1743  No internet service  ...  No internet service      InvalidCategory
# 4473                   No  ...                  Yes                   No
# 3431                   No  ...                  Yes                   No
# 2740                   No  ...                   No                   No
# 1614                  Yes  ...         No-badformat                  Yes
# 7353                  Yes  ...                   No                   No
# 1434                   No  ...                   No                  Yes
# 1337  No internet service  ...  No internet service  No internet service
# 34                     No  ...                   No      InvalidCategory
#
#               StreamingTV      StreamingMovies            Contract  \
# 419                    No      InvalidCategory      Month-to-month
# 1743  No internet service  No internet service  Two year-badformat
# 4473                  Yes                  Yes      Month-to-month
# 3431                  Yes                  Yes      Month-to-month
# 2740                   No                   No      Month-to-month
# 1614                   No                  NaN            Two year
# 7353                  Yes        Yes-badformat      Month-to-month
# 1434      InvalidCategory                  Yes      Month-to-month
# 1337  No internet service  No internet service  Two year-badformat
# 34                     No                   No      Month-to-month
#
#      PaperlessBilling                        PaymentMethod   MonthlyCharges  \
# 419               Yes            Bank transfer (automatic)             75.3
# 1743               No              Credit card (automatic)            24.85
# 4473              Yes  Bank transfer (automatic)-badformat             98.1
# 3431              Yes                     Electronic check           101.05
# 2740              NaN                         Mailed check              NaN
# 1614              Yes            Bank transfer (automatic)            50.95
# 7353              Yes                     Electronic check             98.7
# 1434              Yes                         Mailed check            99.95
# 1337     No-badformat            Bank transfer (automatic)  InvalidCategory
# 34    InvalidCategory            Bank transfer (automatic)            45.25
#
#          TotalCharges Churn
# 419              75.3   Yes
# 1743           1583.5    No
# 4473           2510.7    No
# 3431              NaN   Yes
# 2740             44.4   Yes
# 1614           3521.7    No
# 7353              NaN   Yes
# 1434          1132.75   Yes
# 1337  609.1-badformat    No
# 34              45.25    No
#
# [10 rows x 21 columns]
