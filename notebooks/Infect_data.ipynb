# %%
import pandas as pd
import numpy as np
import random

# %%
file_path = "churn.csv"
df = pd.read_csv(file_path)

# %%
def infect_data(df):
    df_copy = df.copy()

    # 1. Inject Missing Values
    def inject_missing_values(df):
        num_missing = int(df.size * 0.05)
        for _ in range(num_missing):
            ix = (random.randint(0, df.shape[0]-1), random.randint(0, df.shape[1]-1))
            df.iat[ix] = np.nan
        return df

    # 2. Inject Incorrect Data Types
    def inject_incorrect_data_types(df):
        for col in df.select_dtypes(include=['number']).columns:
            df[col] = df[col].apply(lambda x: str(x) if random.random() < 0.05 else x)
        return df

    # 3. Inject Duplicate Rows
    def inject_duplicate_rows(df):
        num_dup = int(df.shape[0] * 0.05)
        dup_rows = df.sample(num_dup, replace=True)
        df = pd.concat([df, dup_rows], ignore_index=True)
        return df

    # 4. Inject Outliers
    def inject_outliers(df):
        for col in df.select_dtypes(include=['number']).columns:
            df[col] = df[col].apply(lambda x: x*10 if random.random() < 0.05 else x)
        return df

    # 5. Inject Inconsistent Data Formats
    def inject_inconsistent_formats(df):
        for col in df.select_dtypes(include=['object']).columns:
            if col == 'SeniorCitizen':
                pass
            else:
                df[col] = df[col].apply(lambda x: f"{x}-badformat" if random.random() < 0.05 else x)
        return df

    # 6. Inject Invalid Range Values
    def inject_invalid_range(df):
        for col in df.columns:
            if "age" in col.lower():
                df[col] = df[col].apply(lambda x: -x if random.random() < 0.05 else x)
        return df

    # 7. Inject Unexpected Categorical Values
    def inject_unexpected_categories(df):
        for col in df.select_dtypes(include=['object']).columns:
            unique_vals = df[col].unique().tolist()
            if len(unique_vals) > 2:  # For categorical columns
                df[col] = df[col].apply(lambda x: "InvalidCategory" if random.random() < 0.05 else x)
        return df

    # Apply all infections
    df_copy = inject_missing_values(df_copy)
    df_copy = inject_incorrect_data_types(df_copy)
    df_copy = inject_duplicate_rows(df_copy)
    df_copy = inject_outliers(df_copy)
    df_copy = inject_inconsistent_formats(df_copy)
    df_copy = inject_invalid_range(df_copy)
    df_copy = inject_unexpected_categories(df_copy)

    return df_copy

# %%
infected_df = infect_data(df)

# %%
infected_df
# Out:
#       customerID          gender SeniorCitizen          Partner Dependents  \
# 0     7590-VHVEG          Female           0.0  InvalidCategory         No
# 1            NaN            Male           0.0               No         No
# 2     3668-QPYBK            Male           0.0               No        NaN
# 3     7795-CFOCW  Male-badformat           0.0               No         No
# 4     9237-HQITU          Female           0.0               No         No
# ...          ...             ...           ...              ...        ...
# 7390  6711-FLDFB          Female           0.0               No         No
# 7391  7526-BEZQB            Male           0.0     No-badformat         No
# 7392  2157-MXBJS            Male           0.0              Yes         No
# 7393  4419-UJMUS            Male           0.0              Yes        Yes
# 7394  3806-DXQOM          Female           0.0               No         No
#
#               tenure     PhoneService     MultipleLines InternetService  \
# 0                1.0               No  No phone service             DSL
# 1               34.0              Yes                No   nan-badformat
# 2                2.0              Yes                No             NaN
# 3               45.0               No  No phone service             DSL
# 4                2.0  InvalidCategory                No     Fiber optic
# ...              ...              ...               ...             ...
# 7390             7.0              Yes               Yes     Fiber optic
# 7391  12.0-badformat              Yes               Yes     Fiber optic
# 7392            13.0              Yes               Yes             DSL
# 7393            69.0              Yes               Yes     Fiber optic
# 7394             4.0               No  No phone service             DSL
#
#        OnlineSecurity  ... DeviceProtection      TechSupport    StreamingTV  \
# 0                  No  ...               No               No            NaN
# 1                 Yes  ...              Yes               No            NaN
# 2                 Yes  ...  InvalidCategory  InvalidCategory             No
# 3                 Yes  ...              Yes              Yes             No
# 4     InvalidCategory  ...               No               No             No
# ...               ...  ...              ...              ...            ...
# 7390               No  ...               No               No             No
# 7391               No  ...               No               No            Yes
# 7392               No  ...              Yes     No-badformat            Yes
# 7393               No  ...               No              Yes  Yes-badformat
# 7394              Yes  ...               No               No             No
#
#      StreamingMovies        Contract PaperlessBilling  \
# 0                 No  Month-to-month              Yes
# 1                 No        One year               No
# 2                 No  Month-to-month              NaN
# 3                 No        One year  InvalidCategory
# 4                 No  Month-to-month  InvalidCategory
# ...              ...             ...              ...
# 7390              No  Month-to-month              Yes
# 7391             Yes  Month-to-month              Yes
# 7392             Yes        One year              Yes
# 7393             Yes        Two year              Yes
# 7394              No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges         Churn
# 0               InvalidCategory          29.85        29.85            No
# 1                  Mailed check          56.95       1889.5            No
# 2                  Mailed check          53.85       108.15           Yes
# 3     Bank transfer (automatic)           42.3      1840.75  No-badformat
# 4               InvalidCategory           70.7       151.65           Yes
# ...                         ...            ...          ...           ...
# 7390           Electronic check           74.9       541.15           Yes
# 7391           Electronic check          96.05       1148.1           Yes
# 7392                        NaN           75.3       989.45           Yes
# 7393           Electronic check          99.35      6856.45            No
# 7394           Electronic check          33.65       137.85           Yes
#
# [7395 rows x 21 columns]

# %%
infected_df['SeniorCitizen'] = pd.to_numeric(infected_df['SeniorCitizen'], errors='coerce')

# %%
# Save the infected dataset
infected_df.to_csv("../data/infected_dataset.csv", index=False)

# Display a sample of the infected data
infected_df.sample(10)
# Out:
#       customerID          gender  SeniorCitizen          Partner Dependents  \
# 1089  4546-FOKWR          Female            0.0               No         No
# 5795  7048-GXDAY  Male-badformat            0.0               No         No
# 105   6180-YBIQI            Male            0.0               No         No
# 2285         NaN            Male            NaN              Yes         No
# 30    3841-NFECX          Female            1.0              Yes         No
# 725   6549-YMFAW            Male            NaN              Yes         No
# 14    5129-JLPIS  Male-badformat            0.0               No         No
# 726   4950-HKQTE          Female            0.0               No         No
# 5845  4581-SSPWD          Female            0.0               No         No
# 2741  1724-BQUHA            Male            1.0  InvalidCategory         No
#
#              tenure   PhoneService     MultipleLines InternetService  \
# 1089           16.0            Yes               Yes     Fiber optic
# 5795           39.0            Yes               Yes     Fiber optic
# 105             5.0             No  No phone service   DSL-badformat
# 2285           53.0            Yes               Yes     Fiber optic
# 30             71.0  Yes-badformat               Yes             NaN
# 725   9.0-badformat            Yes                No              No
# 14             25.0            Yes                No     Fiber optic
# 726            22.0            Yes               Yes              No
# 5845            3.0            Yes               Yes     Fiber optic
# 2741            5.0            Yes      No-badformat     Fiber optic
#
#            OnlineSecurity  ...     DeviceProtection          TechSupport  \
# 1089                  NaN  ...                   No                   No
# 5795                  Yes  ...         No-badformat                   No
# 105                    No  ...                   No                   No
# 2285        Yes-badformat  ...        Yes-badformat                   No
# 30                    Yes  ...                  Yes                  Yes
# 725   No internet service  ...  No internet service  No internet service
# 14                    Yes  ...                  Yes                  NaN
# 726   No internet service  ...  No internet service  No internet service
# 5845                   No  ...                   No                  NaN
# 2741                   No  ...                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 1089                   No                   No  Month-to-month
# 5795                  Yes                  Yes  Month-to-month
# 105                    No                   No  Month-to-month
# 2285      InvalidCategory                  Yes             NaN
# 30                     No                   No        Two year
# 725   No internet service  No internet service  Month-to-month
# 14                    Yes                  Yes  Month-to-month
# 726   No internet service  No internet service        Two year
# 5845                   No                  NaN  Month-to-month
# 2741                  Yes                  Yes  Month-to-month
#
#      PaperlessBilling               PaymentMethod   MonthlyCharges  \
# 1089              Yes     Credit card (automatic)            74.75
# 5795  InvalidCategory            Electronic check            106.4
# 105   InvalidCategory                Mailed check             24.3
# 2285               No            Electronic check             93.9
# 30                Yes     Credit card (automatic)  InvalidCategory
# 725               Yes                Mailed check            21.25
# 14                Yes  Electronic check-badformat            105.5
# 726                No             InvalidCategory            26.25
# 5845              Yes            Electronic check   75.8-badformat
# 2741              Yes            Electronic check             89.5
#
#      TotalCharges            Churn
# 1089      1129.35               No
# 5795      4040.65               No
# 105         100.2               No
# 2285       5029.2  InvalidCategory
# 30        6766.95               No
# 725        204.55               No
# 14        2686.05     No-badformat
# 726         605.9               No
# 5845        246.3  InvalidCategory
# 2741        477.7              Yes
#
# [10 rows x 21 columns]
