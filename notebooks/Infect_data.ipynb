# %%
import pandas as pd
import numpy as np
import random

# %%
file_path = "churn.csv"
df = pd.read_csv(file_path)

# %%
def infect_data(df):
    df_copy = df.copy()

    # 1. Inject Missing Values
    def inject_missing_values(df):
        num_missing = int(df.size * 0.05)
        for _ in range(num_missing):
            ix = (random.randint(0, df.shape[0]-1), random.randint(0, df.shape[1]-1))
            df.iat[ix] = np.nan
        return df

    # 2. Inject Incorrect Data Types
    def inject_incorrect_data_types(df):
        for col in df.select_dtypes(include=['number']).columns:
            df[col] = df[col].apply(lambda x: str(x) if random.random() < 0.05 else x)
        return df

    # 3. Inject Duplicate Rows
    def inject_duplicate_rows(df):
        num_dup = int(df.shape[0] * 0.05)
        dup_rows = df.sample(num_dup, replace=True)
        df = pd.concat([df, dup_rows], ignore_index=True)
        return df

    # 4. Inject Outliers
    def inject_outliers(df):
        for col in df.select_dtypes(include=['number']).columns:
            df[col] = df[col].apply(lambda x: x*10 if random.random() < 0.05 else x)
        return df

    # 5. Inject Inconsistent Data Formats
    def inject_inconsistent_formats(df):
        for col in df.select_dtypes(include=['object']).columns:
            df[col] = df[col].apply(lambda x: f"{x}-badformat" if random.random() < 0.05 else x)
        return df

    # 6. Inject Invalid Range Values
    def inject_invalid_range(df):
        for col in df.columns:
            if "age" in col.lower():
                df[col] = df[col].apply(lambda x: -x if random.random() < 0.05 else x)
        return df

    # 7. Inject Unexpected Categorical Values
    def inject_unexpected_categories(df):
        for col in df.select_dtypes(include=['object']).columns:
            unique_vals = df[col].unique().tolist()
            if len(unique_vals) > 2:  # For categorical columns
                df[col] = df[col].apply(lambda x: "InvalidCategory" if random.random() < 0.05 else x)
        return df

    # Apply all infections
    df_copy = inject_missing_values(df_copy)
    df_copy = inject_incorrect_data_types(df_copy)
    df_copy = inject_duplicate_rows(df_copy)
    df_copy = inject_outliers(df_copy)
    df_copy = inject_inconsistent_formats(df_copy)
    df_copy = inject_invalid_range(df_copy)
    df_copy = inject_unexpected_categories(df_copy)

    return df_copy

# %%
infected_df = infect_data(df)

# %%
infected_df
# Out:
#       customerID           gender    SeniorCitizen          Partner  \
# 0     7590-VHVEG           Female              0.0              Yes
# 1     5575-GNVDE   Male-badformat              0.0               No
# 2     3668-QPYBK  InvalidCategory              0.0  InvalidCategory
# 3     7795-CFOCW             Male              0.0               No
# 4            NaN           Female              0.0               No
# ...          ...              ...              ...              ...
# 7390  1069-QJOEE             Male              NaN              NaN
# 7391  1698-XFZCI             Male              0.0               No
# 7392  3774-VBNXY           Female              0.0              Yes
# 7393  2207-RYYRL             Male              0.0              Yes
# 7394  2828-SLQPF             Male  InvalidCategory               No
#
#      Dependents           tenure PhoneService     MultipleLines  \
# 0            No              1.0           No   InvalidCategory
# 1            No             34.0          Yes                No
# 2            No              2.0          Yes                No
# 3            No             45.0           No  No phone service
# 4            No              2.0          Yes                No
# ...         ...              ...          ...               ...
# 7390        Yes  InvalidCategory          Yes                No
# 7391         No             61.0          Yes               Yes
# 7392        Yes             64.0          Yes               NaN
# 7393        NaN   52.0-badformat          Yes               Yes
# 7394         No             19.0          Yes                No
#
#      InternetService       OnlineSecurity  ...               DeviceProtection  \
# 0                DSL                   No  ...                             No
# 1                DSL                  NaN  ...                            Yes
# 2                NaN                  Yes  ...                             No
# 3                DSL                  Yes  ...                            Yes
# 4        Fiber optic                   No  ...                             No
# ...              ...                  ...  ...                            ...
# 7390              No  No internet service  ...  No internet service-badformat
# 7391     Fiber optic                  NaN  ...                            Yes
# 7392              No  No internet service  ...            No internet service
# 7393             NaN  No internet service  ...                InvalidCategory
# 7394             DSL                   No  ...                             No
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 0            No-badformat                   No                   No
# 1                     NaN                   No                   No
# 2                      No                   No                   No
# 3           nan-badformat                   No                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 7390  No internet service  No internet service  No internet service
# 7391                   No                  Yes                  Yes
# 7392  No internet service  No internet service  No internet service
# 7393  No internet service  No internet service      InvalidCategory
# 7394                   No                   No                   No
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2                NaN              NaN               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7390        One year               No           Electronic check
# 7391        One year              Yes           Electronic check
# 7392        Two year               No               Mailed check
# 7393        Two year               No               Mailed check
# 7394  Month-to-month              Yes  Bank transfer (automatic)
#
#      MonthlyCharges TotalCharges Churn
# 0             29.85        29.85    No
# 1             56.95       1889.5    No
# 2             53.85       108.15   Yes
# 3              42.3          NaN    No
# 4              70.7       151.65   Yes
# ...             ...          ...   ...
# 7390            NaN       505.45    No
# 7391         107.75       6521.9    No
# 7392           20.2      1277.75    No
# 7393          24.55          NaN    No
# 7394           45.0          NaN    No
#
# [7395 rows x 21 columns]

# %%
# Save the infected dataset
infected_df.to_csv("../data/infected_dataset.csv", index=False)

# Display a sample of the infected data
infected_df.sample(10)
# Out:
#                 customerID          gender SeniorCitizen Partner  \
# 5694            0983-TATYJ          Female           0.0     Yes
# 1229            9068-VPWQQ            Male           0.0     Yes
# 4782            6175-IRFIT            Male           0.0      No
# 5933            6496-SLWHQ            Male           1.0     NaN
# 1627            5035-BVCXS  Male-badformat           0.0      No
# 5605            8049-WJCLQ            Male           0.0     Yes
# 2963            4707-YNOQA          Female           0.0     Yes
# 3350  7663-RGWBC-badformat            Male           0.0      No
# 5310            6171-ZTVYB  Male-badformat           0.0     Yes
# 2742            3948-KXDUF            Male           0.0      No
#
#            Dependents tenure     PhoneService    MultipleLines  \
# 5694               No   33.0    Yes-badformat  InvalidCategory
# 1229               No   61.0              Yes              Yes
# 4782               No    5.0              Yes               No
# 5933               No    3.0  InvalidCategory              Yes
# 1627  InvalidCategory    NaN              Yes               No
# 5605              Yes    NaN              Yes               No
# 2963              Yes   34.0              Yes              NaN
# 3350               No    1.0              Yes               No
# 5310               No   43.0              Yes    Yes-badformat
# 2742               No   66.0  InvalidCategory              Yes
#
#      InternetService       OnlineSecurity  ...     DeviceProtection  \
# 5694             DSL                   No  ...                   No
# 1229             DSL                  Yes  ...                  Yes
# 4782             NaN                   No  ...                   No
# 5933     Fiber optic                   No  ...                  NaN
# 1627     Fiber optic                   No  ...                   No
# 5605             DSL                   No  ...      InvalidCategory
# 2963              No  No internet service  ...  No internet service
# 3350             DSL                   No  ...                   No
# 5310             DSL                  Yes  ...                   No
# 2742             DSL                  Yes  ...                  Yes
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 5694                  Yes                   No                   No
# 1229                  Yes                   No      InvalidCategory
# 4782                   No                   No                  Yes
# 5933                   No                  Yes                  Yes
# 1627                   No                   No                   No
# 5605                   No                  NaN                   No
# 2963  No internet service  No internet service  No internet service
# 3350                   No                   No                  NaN
# 5310                  Yes                   No                   No
# 2742                  Yes                   No                   No
#
#             Contract PaperlessBilling              PaymentMethod  \
# 5694        One year              Yes               Mailed check
# 1229        Two year               No    Credit card (automatic)
# 4782  Month-to-month               No               Mailed check
# 5933  Month-to-month              NaN           Electronic check
# 1627             NaN              NaN               Mailed check
# 5605  Month-to-month               No     Mailed check-badformat
# 2963        One year  InvalidCategory    Credit card (automatic)
# 3350  Month-to-month    Yes-badformat               Mailed check
# 5310  Month-to-month               No  Bank transfer (automatic)
# 2742        Two year               No  Bank transfer (automatic)
#
#        MonthlyCharges      TotalCharges            Churn
# 5694            51.45            1758.9               No
# 1229              NaN            4729.3               No
# 4782            78.75            426.35               No
# 5933            105.0            294.45              Yes
# 1627             75.9             866.4               No
# 5605             60.2             563.5              NaN
# 2963             25.6  917.15-badformat               No
# 3350            44.15             44.15              Yes
# 5310  66.25-badformat           2907.35              NaN
# 2742            68.75           4447.55  InvalidCategory
#
# [10 rows x 21 columns]
